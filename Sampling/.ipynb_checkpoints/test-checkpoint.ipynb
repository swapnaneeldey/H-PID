# %%
import abc
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset
import torch.distributions as D
from torch.distributions.mixture_same_family import MixtureSameFamily
device = 'cuda' if torch.cuda.is_available() else 'cpu'

#########################################################################################
def nll_unit_gaussian(data, sigma=1.0):
    data = data.view(data.shape[0], -1)
    loss = 0.5 * np.log(2 * np.pi) + np.log(sigma) + 0.5 * data * data / (sigma ** 2)
    return torch.sum(torch.flatten(loss, start_dim=1), -1)


class BaseSet(abc.ABC, Dataset):
    def __init__(self, len_data=-2333):
        self.num_sample = len_data
        self.data = None
        self.data_ndim = None
        self._gt_ksd = None

    def gt_logz(self):
        raise NotImplementedError

    @abc.abstractmethod
    def energy(self, x):
        return

    def unnorm_pdf(self, x):
        return torch.exp(-self.energy(x))

    # hmt stands for hamiltonian
    def hmt_energy(self, x):
        dim = x.shape[-1]
        x, v = torch.split(x, dim // 2, dim=-1)
        neg_log_p_x = self.sample_energy_fn(x)
        neg_log_p_v = nll_unit_gaussian(v)
        return neg_log_p_x + neg_log_p_v

    @property
    def ndim(self):
        return self.data_ndim

    def sample(self, batch_size):
        del batch_size
        raise NotImplementedError

    def score(self, x):
        with torch.no_grad():
            copy_x = x.detach().clone()
            copy_x.requires_grad = True
            with torch.enable_grad():
                self.energy(copy_x).sum().backward()
                lgv_data = copy_x.grad.data
            return lgv_data

    def log_reward(self, x):
        return -self.energy(x)

    def hmt_score(self, x):
        with torch.no_grad():
            copy_x = x.detach().clone()
            copy_x.requires_grad = True
            with torch.enable_grad():
                self.hmt_energy(copy_x).sum().backward()
                lgv_data = copy_x.grad.data
            return lgv_data
            
######################################################


class TwentyFiveGaussianMixture(BaseSet):
    def __init__(self, device, dim=2):
        super().__init__()
        self.data = torch.tensor([0.0])
        self.device = device

        modes = torch.Tensor([(a, b) for a in [-10, -5, 0, 5, 10] for b in [-10, -5, 0, 5, 10]]).to(self.device)

        nmode = 25
        self.nmode = nmode

        self.data_ndim = dim

        self.gmm = [D.MultivariateNormal(loc=mode.to(self.device),
                                         covariance_matrix=0.3 * torch.eye(self.data_ndim, device=self.device))
                    for mode in modes]

    def gt_logz(self):
        return 0.

    def energy(self, x):
        log_prob = torch.logsumexp(torch.stack([mvn.log_prob(x) for mvn in self.gmm]), dim=0,
                           keepdim=False) - torch.log(torch.tensor(self.nmode, device=self.device))
        return -log_prob

    def sample(self, batch_size):
        samples = torch.cat([mvn.sample((batch_size // self.nmode,)) for mvn in self.gmm], dim=0).to(self.device)
        return samples

    def viz_pdf(self, fsave="25gmm-density.png"):
        x = torch.linspace(-15, 15, 100).to(self.device)
        y = torch.linspace(-15, 15, 100).to(self.device)
        X, Y = torch.meshgrid(x, y)
        x = torch.stack([X.flatten(), Y.flatten()], dim=1)  # ?

        density = self.unnorm_pdf(x)
        return x, density

    def __getitem__(self, idx):
        del idx
        return self.data[0]
##########################################################################

# %%
gmm = TwentyFiveGaussianMixture(device=device, dim=2)

# Generate 512 samples
samples = gmm.sample(256)
plt.plot(samples[:,0].cpu().numpy(), samples[:,1].cpu().numpy(), 'o', color='blue')

# %%
def normal_is(x, beta, t, num_samples):
    """
    Generates `num_samples` for each sample in the input batch `x` using
    a multivariate normal distribution with computed means and covariances.

    Parameters:
    - x: tensor of shape (batch_size, dim) where batch_size is the number of input samples.
    - beta: scalar value for covariance calculation.
    - t: scalar value for time.
    - num_samples: the number of new samples to generate for each `x` in the batch.
    
    Returns:
    - covar_inv: inverse covariance matrix for each sample (batch_size, dim, dim).
    - mean: mean tensor used for generating new samples (batch_size, dim).
    - new_samples: tensor of shape (batch_size, num_samples, dim) with generated samples.
    """
    # Ensure the code runs on the same device as x (either CPU or CUDA)
    device = x.device

    batch_size, d = x.shape  # batch_size is the number of x samples, d is dimensionality
    beta_sqrt = torch.sqrt(beta).to(device)
    
    # Compute coth terms
    coth1 = 1 / torch.tanh(beta_sqrt)
    coth2 = 1 / torch.tanh((1 - t) * beta_sqrt)
    
    # Compute coefficients and covariance
    coeff = beta_sqrt * (coth2 - coth1)
    covar = coeff * torch.eye(d, device=device)  # Covariance matrix (same for all x)
    covar_inv = torch.eye(d, device=device) / coeff  # Inverse covariance matrix
    covar_sqrt = torch.sqrt(coeff) * torch.eye(d, device=device)  # Covariance square root
    
    # Compute the mean for each x in the batch
    mean = x / (torch.cosh((1 - t) * beta_sqrt) - torch.sinh((1 - t) * beta_sqrt) * coth1)  # Shape: (batch_size, d)

    # Now we generate multiple samples for each mean
    # Shape of z: (batch_size, num_samples, dim)
    z = torch.randn(batch_size, num_samples, d, device=device)

    # Generate new samples by broadcasting the mean and covariance
    # Shape: (batch_size, num_samples, dim)
    new_samples = mean.unsqueeze(1) + z @ covar_sqrt  # Broadcasting mean across num_samples

    return covar_inv, mean, new_samples

def compute_control(x, y, y_star, H_inv, beta, t, energy_function):
    """
    Computes the control vector based on the given energy function and parameters.

    This function uses the provided energy function and a custom equation involving
    softmax over sampled values of y, computes a weighted sum of y, and then calculates
    a control vector `u` for each x.

    Parameters:
    - x: Tensor of shape (batch_size, dim) representing input x.
    - y: Tensor of shape (batch_size, num_samples, dim), sampled y values for each x.
    - y_star: Tensor of shape (batch_size, dim), the mean vector for each x.
    - H_inv: Tensor of shape (dim, dim), the inverse covariance matrix.
    - beta: Scalar representing a parameter for the equation.
    - t: Scalar time factor for the equation.
    - energy_function: A function E(y) that returns the energy for each y, shape (batch_size, num_samples).

    Returns:
    - u: Tensor of shape (batch_size, dim), the computed control vector for each x.
    """
    
    # Ensure the code runs on the same device as x
    device = x.device

    # Hyperbolic functions of sqrt(beta) and (1-t)*sqrt(beta)
    beta_sqrt = torch.sqrt(beta).to(device)
    cosh_term = torch.cosh((1 - t) * beta_sqrt).to(device)
    sinh_term = torch.sinh((1 - t) * beta_sqrt).to(device)
    coth_beta = 1 / torch.tanh(beta_sqrt).to(device)

    # Step 1: Compute the energy term: -E(y)
    E_y = energy_function(y)  # Shape: (batch_size, num_samples)
    
    # Step 2: Mahalanobis distance: (y - y_star)^T H_inv (y - y_star)
    diff = y - y_star.unsqueeze(1)  # Shape: (batch_size, num_samples, dim)
    mahalanobis = 0.5 * torch.einsum('bnd,dd,bnd->bn', diff, H_inv.to(device), diff)  # Shape: (batch_size, num_samples)
    
    # Step 3: Compute interaction term
    x_squared = x.unsqueeze(1) ** 2  # Shape: (batch_size, 1, dim)
    y_squared = y ** 2  # Shape: (batch_size, num_samples, dim)
    interaction_numerator = (x_squared + y_squared) * cosh_term - 2 * (x.unsqueeze(1) * y)  # Shape: (batch_size, num_samples, dim)
    interaction = -beta_sqrt * interaction_numerator.sum(dim=-1) / (2 * sinh_term)  # Shape: (batch_size, num_samples)
    
    # Step 4: Quadratic penalty on y
    quadratic_penalty = -0.5 * y_squared.sum(dim=-1) * beta_sqrt * coth_beta  # Shape: (batch_size, num_samples)

    # Step 5: Combine all terms
    exponent = -E_y + mahalanobis + interaction + quadratic_penalty  # Shape: (batch_size, num_samples)
    
    # Step 6: Apply softmax over the num_samples dimension
    softmax_result = torch.softmax(exponent, dim=1)  # Shape: (batch_size, num_samples)

    # Step 7: Compute the weighted sum of y using the softmax result
    weighted_y = softmax_result.unsqueeze(-1) * y  # Shape: (batch_size, num_samples, dim)
    weighted_sum = weighted_y.sum(dim=1)  # Shape: (batch_size, dim)
    #print(weighted_sum.shape)
    
    # Step 8: Compute the control vector u
    u = (weighted_sum - x * torch.cosh((1 - t) * beta_sqrt)) * (beta_sqrt / torch.sinh((1 - t) * beta_sqrt))

    return u


def energy_function(y):
    # `gmm.energy` expects input of shape (batch_size * num_samples, dim),
    # so we need to reshape y accordingly.
    batch_size, num_samples, dim = y.shape
    y_flat = y.view(-1, dim)  # Flatten y into shape (batch_size * num_samples, dim)
    
    # Compute the energy using the GMM energy function
    energy = gmm.energy(y_flat)  # Shape: (batch_size * num_samples)
    
    # Reshape back to (batch_size, num_samples)
    return energy.view(batch_size, num_samples)

# %%
# Example usage:
batch_size, num_samples, dim = 20, 100, 2

x = torch.randn(batch_size, dim, device=device)  # x: shape (batch_size, dim)
y = torch.randn(batch_size, num_samples, dim, device=device)  # y: shape (batch_size, num_samples, dim)
y_star = torch.mean(y, dim=1)  # Example mean vector y*: shape (batch_size, dim)
H_inv = torch.eye(dim, device=device)  # Example inverse covariance matrix: shape (dim, dim)
beta = torch.tensor(0.5, device=device)  # Example scalar for beta
t = torch.tensor(0.3, device=device)  # Example scalar for time



# Compute the control vector
u = compute_control(x, y, y_star, H_inv, beta, t, energy_function)

print(f"Control vector shape: {u.shape}")  # Expected shape: (batch_size, dim)
#print(u)
# Out:
# Control vector shape: torch.Size([20, 2])

# %%
eps = 1e-3
tt = torch.linspace(eps, 1-eps, 101).to(device)
delta_t = tt[1] - tt[0]
beta = torch.tensor(0.5, device=device)  # Example scalar for beta

batch_size, num_samples, dim = 512, 1024, 2

x0 = torch.zeros(batch_size, dim, device=device) 

#plt.savefig('0.pdf')
for t in tt:
    H_inv, y_star, y = normal_is(x0, beta, t, num_samples)
    u = compute_control(x0, y, y_star, H_inv, beta, t, energy_function)
    print(t.item(), end=' ', flush=True)
    x0 = x0 + u * delta_t + torch.sqrt(delta_t) * torch.randn_like(u).to(device)
# Out:
# 0.0010000000474974513
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 13
#      11 for t in tt:
#      12     H_inv, y_star, y = normal_is(x0, beta, t, num_samples)
# ---> 13     u = compute_control(x0, y, y_star, H_inv, beta, t, energy_function)
#      14     print(t.item(), end=' ', flush=True)
#      15     x0 = x0 + u * delta_t + torch.sqrt(delta_t) * torch.randn_like(u).to(device)
#
# Cell In[3], line 77, in compute_control(x, y, y_star, H_inv, beta, t, energy_function)
#      74 coth_beta = 1 / torch.tanh(beta_sqrt).to(device)
#      76 # Step 1: Compute the energy term: -E(y)
# ---> 77 E_y = energy_function(y)  # Shape: (batch_size, num_samples)
#      79 # Step 2: Mahalanobis distance: (y - y_star)^T H_inv (y - y_star)
#      80 diff = y - y_star.unsqueeze(1)  # Shape: (batch_size, num_samples, dim)
#
# Cell In[3], line 116, in energy_function(y)
#     113 y_flat = y.view(-1, dim)  # Flatten y into shape (batch_size * num_samples, dim)
#     115 # Compute the energy using the GMM energy function
# --> 116 energy = gmm.energy(y_flat)  # Shape: (batch_size * num_samples)
#     118 # Reshape back to (batch_size, num_samples)
#     119 return energy.view(batch_size, num_samples)
#
# Cell In[1], line 95, in TwentyFiveGaussianMixture.energy(self, x)
#      94 def energy(self, x):
# ---> 95     log_prob = torch.logsumexp(torch.stack([mvn.log_prob(x) for mvn in self.gmm]), dim=0,
#      96                        keepdim=False) - torch.log(torch.tensor(self.nmode, device=self.device))
#      97     return -log_prob
#
# File ~/.venv/lib/python3.12/site-packages/torch/distributions/multivariate_normal.py:249, in MultivariateNormal.log_prob(self, value)
#     247     self._validate_sample(value)
#     248 diff = value - self.loc
# --> 249 M = _batch_mahalanobis(self._unbroadcasted_scale_tril, diff)
#     250 half_log_det = (
#     251     self._unbroadcasted_scale_tril.diagonal(dim1=-2, dim2=-1).log().sum(-1)
#     252 )
#     253 return -0.5 * (self._event_shape[0] * math.log(2 * math.pi) + M) - half_log_det
#
# File ~/.venv/lib/python3.12/site-packages/torch/distributions/multivariate_normal.py:63, in _batch_mahalanobis(bL, bx)
#      60 flat_x = bx.reshape(-1, flat_L.size(0), n)  # shape = c x b x n
#      61 flat_x_swap = flat_x.permute(1, 2, 0)  # shape = b x n x c
#      62 M_swap = (
# ---> 63     torch.linalg.solve_triangular(flat_L, flat_x_swap, upper=False).pow(2).sum(-2)
#      64 )  # shape = b x c
#      65 M = M_swap.t()  # shape = c x b
#      67 # Now we revert the above reshape and permute operators.
#
# KeyboardInterrupt:

# %%
i = 0

x0 = torch.zeros(batch_size, dim, device=device) 

for t in tt:
    H_inv, y_star, y = normal_is(x0, beta, t, num_samples)
    u = compute_control(x0, y, y_star, H_inv, beta, t, energy_function)
    print(t.item(), end=' ', flush=True)
    plt.plot(x0[:,0].cpu().numpy(), x0[:,1].cpu().numpy(), 'o', color='blue')
    plt.grid()
    plt.savefig(f'{i}.pdf')
    i += 1
    #break; 
    x0 = x0 + u * delta_t + torch.sqrt(delta_t) * torch.randn_like(u).to(device)
# Out:
# 0.0010000000474974513 0.010980000719428062 0.020960001274943352 0.03094000183045864 0.04092000052332878 0.05090000107884407 0.06088000163435936 0.07086000591516495 0.08084000647068024 0.09082000702619553 0.10080000758171082 0.1107800081372261 0.1207600086927414 0.1307400017976761 0.14072000980377197 0.15070000290870667 0.16068001091480255 0.17066000401973724 0.18064001202583313 0.19062000513076782 0.2006000131368637 0.2105800062417984 0.2205600142478943 0.23054000735282898 0.24052001535892487 0.25050002336502075 0.26048001646995544 0.27046000957489014 0.28044000267982483 0.2904200255870819 0.3004000186920166 0.3103800117969513 0.320360004901886 0.33034002780914307 0.34032002091407776 0.35030001401901245 0.36028000712394714 0.3702600300312042 0.3802400231361389 0.3902200162410736 0.4002000093460083 0.4101800322532654 0.4201600253582001 0.43014001846313477 0.44012001156806946 0.45010003447532654 0.46008002758026123 0.4700600206851959 0.4800400137901306 0.4900200366973877 0.5 0.5099799633026123 0.5199599862098694 0.5299400091171265 0.5399199724197388 0.5498999953269958 0.5598800182342529 0.5698599815368652 0.5798400044441223 0.5898199677467346 0.5997999906539917 0.6097800135612488 0.6197599768638611 0.6297399997711182 0.6397199630737305 0.6496999859809875 0.6596800088882446 0.6696599721908569 0.679639995098114 0.6896200180053711 0.6995999813079834 0.7095800042152405 0.7195600271224976 0.7295399904251099 0.7395200133323669 0.7494999766349792 0.7594799995422363 0.7694600224494934 0.7794399857521057 0.7894200086593628 0.7993999719619751 0.8093799948692322 0.8193600177764893 0.8293399810791016
